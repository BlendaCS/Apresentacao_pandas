# %%
import pandas as pd

# %%
df1 = pd.read_excel("Aracaju.xlsx",)
df2 = pd.read_excel("Fortaleza.xlsx")
df3 = pd.read_excel("Natal.xlsx")
df4 = pd.read_excel("Recife.xlsx")
df5 = pd.read_excel("Salvador.xlsx")

# %%
df2.head()
# Out:
#       Cidade       Data  Vendas  LojaID  Qtde
# 0  Fortaleza 2019-01-01   45.27    1002     2
# 1  Fortaleza 2019-01-01  115.61    1002     3
# 2  Fortaleza 2019-02-10   35.33    1004     3
# 3  Fortaleza 2019-02-10   20.95    1004     6
# 4  Fortaleza 2019-01-01   14.25    1004     6

# %%
df = pd.concat([df1,df2,df3,df4,df5])

# %%
df.head()
# Out:
#     Cidade       Data  Vendas  LojaID  Qtde
# 0  Aracaju 2018-01-01  142.00    1520     1
# 1  Aracaju 2018-01-01   14.21    1522     6
# 2  Aracaju 2018-01-01   71.55    1520     1
# 3  Aracaju 2018-01-01    3.01    1521     7
# 4  Aracaju 2018-01-01   24.51    1522     8

# %%
df.tail()
# Out:
#        Cidade       Data  Vendas  LojaID  Qtde
# 235  Salvador 2019-01-03   41.84    1034     1
# 236  Salvador 2019-01-03  126.29    1035     3
# 237  Salvador 2019-01-03   38.06    1036     3
# 238  Salvador 2019-01-03  139.64    1035     1
# 239  Salvador 2019-01-03  161.41    1037     3

# %%
df.sample(5)
# Out:
#      Cidade       Data  Vendas  LojaID  Qtde
# 121  Recife 2019-03-02   41.55     981     3
# 59   Recife 2019-01-01   89.39     983     5
# 58    Natal 2018-12-23  272.00     853     3
# 28   Recife 2019-01-01  123.69     983     3
# 51    Natal 2018-01-21  859.00     852     4

# %%
df.dtypes
# Out:
# Cidade            object
# Data      datetime64[ns]
# Vendas           float64
# LojaID             int64
# Qtde               int64
# dtype: object

# %%
df["LojaID"] = df["LojaID"].astype("object")

# %%
df.dtypes
# Out:
# Cidade            object
# Data      datetime64[ns]
# Vendas           float64
# LojaID            object
# Qtde               int64
# dtype: object

# %%
df.head()
# Out:
#     Cidade       Data  Vendas LojaID  Qtde
# 0  Aracaju 2018-01-01  142.00   1520     1
# 1  Aracaju 2018-01-01   14.21   1522     6
# 2  Aracaju 2018-01-01   71.55   1520     1
# 3  Aracaju 2018-01-01    3.01   1521     7
# 4  Aracaju 2018-01-01   24.51   1522     8

# %%
df.isnull().sum()
# Out:
# Cidade    0
# Data      0
# Vendas    0
# LojaID    0
# Qtde      0
# dtype: int64

# %%
#criando uma nova coluna
df["Receita"] = df["Vendas"].mul(df["Qtde"])

# %%
df.head()
# Out:
#     Cidade       Data  Vendas LojaID  Qtde  Receita
# 0  Aracaju 2018-01-01  142.00   1520     1   142.00
# 1  Aracaju 2018-01-01   14.21   1522     6    85.26
# 2  Aracaju 2018-01-01   71.55   1520     1    71.55
# 3  Aracaju 2018-01-01    3.01   1521     7    21.07
# 4  Aracaju 2018-01-01   24.51   1522     8   196.08

# %%
df["Receita"].max()
# Out:
# 3544.0

# %%
df["Receita"].min()
# Out:
# 3.34

# %%
df.nlargest(3,"Receita")
# Out:
#    Cidade       Data  Vendas LojaID  Qtde  Receita
# 7   Natal 2019-03-18   886.0    853     4   3544.0
# 51  Natal 2018-01-21   859.0    852     4   3436.0
# 55  Natal 2019-01-08   859.0    854     4   3436.0

# %%
df.nsmallest(3,"Receita")
# Out:
#       Cidade       Data  Vendas LojaID  Qtde  Receita
# 118  Aracaju 2018-01-01    3.34   1522     1     3.34
# 65    Recife 2019-01-01    4.01    981     1     4.01
# 92     Natal 2019-01-02    4.57   1035     1     4.57

# %%
df.groupby("Cidade")["Receita"].sum()
# Out:
# Cidade
# Aracaju       48748.25
# Fortaleza     37913.97
# Natal        167227.52
# Recife        51936.51
# Salvador      40596.73
# Name: Receita, dtype: float64

# %%
df.sort_values("Receita", ascending=False).head(5)
# Out:
#    Cidade       Data  Vendas LojaID  Qtde  Receita
# 7   Natal 2019-03-18   886.0    853     4   3544.0
# 55  Natal 2019-01-08   859.0    854     4   3436.0
# 51  Natal 2018-01-21   859.0    852     4   3436.0
# 30  Natal 2018-10-02   856.0    853     4   3424.0
# 41  Natal 2018-05-20   835.0    852     4   3340.0

# %%
df.sort_values("Vendas", ascending=False).head(5)
# Out:
#    Cidade       Data  Vendas LojaID  Qtde  Receita
# 7   Natal 2019-03-18   886.0    853     4   3544.0
# 40  Natal 2018-01-10   885.0    853     3   2655.0
# 82  Natal 2019-03-07   868.0    854     3   2604.0
# 24  Natal 2018-04-22   868.0    854     3   2604.0
# 51  Natal 2018-01-21   859.0    852     4   3436.0

# %%
#Trabalhando com datas
df["Data"].head()
# Out:
# 0   2018-01-01
# 1   2018-01-01
# 2   2018-01-01
# 3   2018-01-01
# 4   2018-01-01
# Name: Data, dtype: datetime64[ns]

# %%
df["Data"] = df["Data"].astype("int64")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: casting datetime64[ns] values to int64 with .astype(...) is deprecated and will raise in a future version. Use .view(...) instead.
#   """Entry point for launching an IPython kernel.

# %%
df.dtypes
# Out:
# Cidade      object
# Data         int64
# Vendas     float64
# LojaID      object
# Qtde         int64
# Receita    float64
# dtype: object

# %%
df["Data"] = pd.to_datetime(df["Data"])

# %%
df.dtypes
# Out:
# Cidade             object
# Data       datetime64[ns]
# Vendas            float64
# LojaID             object
# Qtde                int64
# Receita           float64
# dtype: object

# %%
df.groupby(df["Data"].dt.year)["Receita"].sum()
# Out:
# Data
# 2018    118176.53
# 2019    228246.45
# Name: Receita, dtype: float64

# %%
df["Ano_Venda"] = df["Data"].dt.year

# %%
df.sample(5)
# Out:
#         Cidade       Data  Vendas LojaID  Qtde  Receita  Ano_Venda
# 154   Salvador 2019-01-02    9.58   1037     1     9.58       2019
# 20      Recife 2019-01-01   42.35    982     3   127.05       2019
# 115  Fortaleza 2019-03-02   12.23    981     3    36.69       2019
# 199      Natal 2019-01-02  153.87   1036     3   461.61       2019
# 173      Natal 2019-01-02   31.77   1034     2    63.54       2019

# %%
df.rename(columns={"Ano_Venda":"Ano_venda"}, inplace=True)

# %%
df["Mes_venda"], df["Dia_venda"] = (df["Data"].dt.month, df["Data"].dt.day)

# %%
df.sample(5)
# Out:
#         Cidade       Data  Vendas LojaID  Qtde  Receita  Ano_venda  Mes_venda  \
# 88    Salvador 2019-01-01   31.20   1036     1    31.20       2019          1
# 71     Aracaju 2018-01-01  228.27   1523     6  1369.62       2018          1
# 123    Aracaju 2018-01-01  115.19   1523     6   691.14       2018          1
# 112  Fortaleza 2019-03-02  133.59    982     1   133.59       2019          3
# 170      Natal 2019-01-02    9.26   1035     3    27.78       2019          1
#
#      Dia_venda  Semestre_venda
# 88           1               1
# 71           1               1
# 123          1               1
# 112          2               1
# 170          2               1

# %%
df["Data"].min()
# Out:
# Timestamp('2018-01-01 00:00:00')

# %%
df["Semestre_venda"]=df["Data"].dt.quarter

# %%
df.sample(5)
# Out:
#         Cidade       Data  Vendas LojaID  Qtde  Receita  Ano_venda  Mes_venda  \
# 196      Natal 2019-01-02  145.09   1036     2   290.18       2019          1
# 119      Natal 2019-01-02  136.37   1034     2   272.74       2019          1
# 174      Natal 2019-01-02   35.30   1037     1    35.30       2019          1
# 204      Natal 2019-01-02  151.41   1037     2   302.82       2019          1
# 125  Fortaleza 2019-03-02   37.60    983     4   150.40       2019          3
#
#      Dia_venda  Semestre_venda
# 196          2               1
# 119          2               1
# 174          2               1
# 204          2               1
# 125          2               1

# %%
df.rename(columns={"Semestre_venda":"Trimestre_venda"}, inplace=True)

# %%
vendas_marco_19 = df.loc[(df["Data"].dt.year==2019)& (df["Data"].dt.month==3)]

# %%
vendas_marco_19.sample(10)
# Out:
#         Cidade       Data  Vendas LojaID  Qtde  Receita  Ano_venda  Mes_venda  \
# 116  Fortaleza 2019-03-02   79.10    982     2   158.20       2019          3
# 71       Natal 2019-03-20  840.00    854     3  2520.00       2019          3
# 114  Fortaleza 2019-03-02   16.82    983     4    67.28       2019          3
# 123  Fortaleza 2019-03-02   20.22    981     6   121.32       2019          3
# 141  Fortaleza 2019-03-02  182.75    983     8  1462.00       2019          3
# 115     Recife 2019-03-02   12.23    981     3    36.69       2019          3
# 124     Recife 2019-03-02   47.98    983     7   335.86       2019          3
# 117  Fortaleza 2019-03-02   15.42    983     8   123.36       2019          3
# 115   Salvador 2019-03-02  202.33   1035     2   404.66       2019          3
# 46       Natal 2019-03-26  753.00    853     2  1506.00       2019          3
#
#      Dia_venda  Trimestre_venda
# 116          2                1
# 71          20                1
# ...

# %%
#Visualização de dados com gráficos
#retorna os valores totais que cada dado aparece nas linhas
df["LojaID"].value_counts(ascending=False)
# Out:
# 1036    117
# 1035    112
# 1037    101
# 1034     67
# 983      65
# 982      44
# 1522     41
# 1520     39
# 980      36
# 981      31
# 1005     30
# 1002     30
# 852      29
# 1523     29
# 1004     28
# 854      28
# 853      26
# 1521     21
# 1003     20
# Name: LojaID, dtype: int64

# %%
#colocar os dados em gráfico pelo value_counts
df["LojaID"].value_counts(ascending=False).plot.bar();

# %%
df["LojaID"].value_counts(ascending=True).plot.barh();

# %%
df.groupby(df["Ano_venda"])["Receita"].sum().plot.pie();

# %%
df["Cidade"].value_counts()
# Out:
# Natal        240
# Salvador     240
# Fortaleza    142
# Recife       142
# Aracaju      130
# Name: Cidade, dtype: int64

# %%
#colocando títulos e eixos nos gráficos
import matplotlib.pyplot as plt
df["Cidade"].value_counts().plot.bar(title= "Total vendas por cidade")
plt.xlabel("Cidade")
plt.ylabel("Total vendas");

# %%
df["Cidade"].value_counts().plot.bar(title= "Total vendas por cidade", color="orange")
plt.xlabel("Cidade")
plt.ylabel("Total vendas");

# %%
plt.style.use("ggplot")

# %%
df.groupby(df["Mes_venda"])["Qtde"].sum().plot(title="Total de Produtos Vendidos x Mês")
plt.xlabel("Total de Produtos Vendidos")
plt.ylabel("Mês de Venda")
plt.legend();

# %%
df.groupby(df["Mes_venda"])["Qtde"].sum()
# Out:
# Mes_venda
# 1     2208
# 2      144
# 3      467
# 4       23
# 5       17
# 6       13
# 7       13
# 8        2
# 9       10
# 10      14
# 11       2
# 12       3
# Name: Qtde, dtype: int64

# %%
df_2019 = df[df["Ano_venda"] == 2019]

# %%
df_2019.groupby(df_2019["Mes_venda"])["Qtde"].sum().plot(marker= "o")
plt.xlabel("Mês")
plt.ylabel("Total de Produtos Vendidos")
plt.legend();

# %%
df_2019.groupby(df_2019["Mes_venda"])["Qtde"].sum()
# Out:
# Mes_venda
# 1    1541
# 2     128
# 3     460
# 4      12
# Name: Qtde, dtype: int64

# %%
plt.hist(df["Qtde"],color="orange");

# %%
df["Qtde"].value_counts()
# Out:
# 3     221
# 2     193
# 1     191
# 4      85
# 6      61
# 5      54
# 7      38
# 8      31
# 9      14
# 10      6
# Name: Qtde, dtype: int64

# %%
plt.scatter(x=df_2019["Dia_venda"],y=df_2019["Receita"]);

# %%
df_2019.groupby(df_2019["Mes_venda"])["Qtde"].sum().plot(marker="o", title = "Quantidade de Produtos Vendidos x Mês")
plt.xlabel("Mês")
plt.ylabel("Quantidade de Produtos Vendidos")
plt.legend();
plt.savefig("Qtfe Produto Vendido x Mês.png")
